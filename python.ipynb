# %% [markdown]
# # Vẽ đồ thị

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3],[4,5,6])
plt.show()

# %%
print("hello word")
# Out:
# hello word

# %%
n = int(input())

for i in range (n):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import python
